# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import data_ops

import numpy as np
import pandas as pd

# %%
json_data = data_ops.load()

# %%
dfs = data_ops.join_players(json_data)

# %%
df = dfs['quarterback']
df[df['year'] == 2022]
# Out:
#    week   opp result  score cmp  passing_att  cmp%  passing_Yard  passing_td  \
# 0     1  @LAR      W  31-10  26         31.0  83.9         297.0         3.0
# 1     2   TEN      W   41-7  26         38.0  68.4         317.0         4.0
# 0     1  @DAL      W   19-3  18         27.0  66.7         212.0         1.0
# 1     2   @NO      W  20-10  18         34.0  52.9         190.0         1.0
# 0     1    LV      W  24-19  26         34.0  76.5         279.0         3.0
# ..  ...   ...    ...    ...  ..          ...   ...           ...         ...
# 1     2    NE      L  14-17  21         33.0  63.6         168.0         1.0
# 0     1    KC      L  21-44   2          4.0  50.0          12.0         0.0
# 0     1   IND      T  20-20   0          0.0  None           0.0         0.0
# 1     2  @DEN      L   9-16   0          0.0  None           0.0         0.0
# 0     2  @BUF      L   7-41   1          4.0  25.0           6.0         0.0
#
# ...
